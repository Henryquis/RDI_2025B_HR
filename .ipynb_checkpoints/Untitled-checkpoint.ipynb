# %%
import nbformat

with open("07vectordbRamirezHenry.ipynb", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]

with open("07vectordbRamirezHenry_clean.ipynb", "w", encoding="utf-8") as f:
    nbformat.write(nb, f)
